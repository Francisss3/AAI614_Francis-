# %% [markdown]
# <a href="https://colab.research.google.com/github/Francisss3/AAI614_Francis-/blob/main/Notebook2_4_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 2.4: Exploratory Data Analysis*
#
# <a href="https://colab.research.google.com/github/harmanani/AAI614/blob/main/Week%202/Notebook2.4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import subprocess
import pkg_resources

required = {'autoviz'}
installed = {pkg.key for pkg in pkg_resources.working_set}
missing = required - installed

if missing:
    python = sys.executable
    subprocess.check_call([python, '-m', 'pip', 'install', *missing], stdout=subprocess.DEVNULL)

import pandas as pd
import numpy as np
from autoviz import AutoViz_Class
import ssl

ssl._create_default_https_context = ssl._create_unverified_context
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
students = pd.read_csv("https://raw.githubusercontent.com/harmanani/AAI614/main/Week%202/students.csv")

# %% [markdown]
# ##### If you don’t have a target variable you can leave it blank:

# %%
target_variable = ''

# %%
AV = AutoViz_Class()
sep = ','


dft = AV.AutoViz(students, sep, depVar=target_variable, dfte="",
           header=0, verbose=1,
            lowess=False,chart_format='bokeh',max_rows_analyzed=500,max_cols_analyzed=30)
# Out:
# Shape of your Data Set loaded: (9, 6)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  1
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     6 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Student Name']
# ...

# %%
print(students.columns)
# Out:
# Index(['Student Name', 'Avg_Hours_Studied_per_week', 'GPA', 'University',
#        'Sense of Humour (0-5)', 'Salary'],
#       dtype='object')

# %%
target_variable = 'Salary'

# %%
dft = AV.AutoViz(students, sep=sep, depVar=target_variable, dfte="",
                 header=0, verbose=1,
                 lowess=False, chart_format='bokeh', max_rows_analyzed=500, max_cols_analyzed=30)
# Out:
# Shape of your Data Set loaded: (9, 6)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  1
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     5 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Student Name']
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram for numeric variables
students[['Salary', 'Avg_Hours_Studied_per_week', 'GPA']].hist(bins=10, figsize=(15, 5))
plt.suptitle('Histograms of Numeric Variables')
plt.show()

# Count plot for categorical variables
plt.figure(figsize=(12, 5))
sns.countplot(x='University', data=students)
plt.title('Count of Students by University')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(8, 5))
sns.countplot(x='Sense of Humour (0-5)', data=students)
plt.title('Count of Students by Sense of Humour')
plt.show()

# %%
# Scatter plot: Salary vs Avg_Hours_Studied_per_week
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Avg_Hours_Studied_per_week', y='Salary', data=students)
plt.title('Salary vs Avg Hours Studied per Week')
plt.xlabel('Average Hours Studied per Week')
plt.ylabel('Salary')
plt.show()

# Scatter plot: Salary vs GPA
plt.figure(figsize=(8, 6))
sns.scatterplot(x='GPA', y='Salary', data=students)
plt.title('Salary vs GPA')
plt.xlabel('GPA')
plt.ylabel('Salary')
plt.show()

# %%
# Box plot: Salary by University
plt.figure(figsize=(12, 6))
sns.boxplot(x='University', y='Salary', data=students)
plt.title('Salary by University')
plt.xticks(rotation=45)
plt.show()

# Box plot: Salary by Sense of Humour
plt.figure(figsize=(8, 6))
sns.boxplot(x='Sense of Humour (0-5)', y='Salary', data=students)
plt.title('Salary by Sense of Humour')
plt.show()

# %%
# Remove dollar sign and 'k', then convert to numeric
students['Salary'] = students['Salary'].replace('[\$,k]', '', regex=True).astype(float) * 1000

# plotting the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(students[['Salary', 'Avg_Hours_Studied_per_week', 'GPA']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
